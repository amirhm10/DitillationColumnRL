# %%
from Simulation.mpc import *
from Simulation.systemFunctions import DistillationColumnAspen
from utils.helpers import *

# %% [markdown]
# ## Initialize the system

# %%
# System and Snapshot paths
path = r"C:/Users\HAMEDI\Desktop\FinalDocuments\FinalDocuments\C2SplitterControlFiles\AspenFiles\dynsim\Plant\C2S_SS_simulation9.dynf"
path_snaps = r"C:/Users\HAMEDI\Desktop\FinalDocuments\FinalDocuments\C2SplitterControlFiles\AspenFiles\dynsim\Plant\AM_C2S_SS_simulation9"

# %%
# First initiate the system
# Nominal Conditions
nominal_conditions =  np.array([1.50032484e+05, -2.10309105e+01, 2.08083248e+01, 6.30485237e-01, 3.69514734e-01, -2.40000000e+01])

# Steady State inputs
ss_inputs = np.array([320000.0, 110.0])

# Sampling time of the system
delta_t = 1 / 6 # 10 mins

# %%
# steady state values
dl = DistillationColumnAspen(path, ss_inputs, nominal_conditions)
steady_states={"ss_inputs":dl.ss_inputs,
               "y_ss":dl.y_ss}
print(steady_states)
dl.close(path_snaps)
# Out:
# Initialization has been completed
# Steady State has been completed
# System is in open loop condition now!
# Steady state reached!
# {'ss_inputs': array([3.2e+05, 1.1e+02]), 'y_ss': array([  0.1003974 , -22.95514339])}
# Deleted the last created snapshot starting with 'snp': C:/Users\HAMEDI\Desktop\FinalDocuments\FinalDocuments\C2SplitterControlFiles\AspenFiles\dynsim\Plant\AM_C2S_SS_simulation9\snpA0000.snp
# Deleted the last created snapshot starting with 'snp': C:/Users\HAMEDI\Desktop\FinalDocuments\FinalDocuments\C2SplitterControlFiles\AspenFiles\dynsim\Plant\AM_C2S_SS_simulation9\snpA0001.snp

# %% [markdown]
# ## Loading the system matrices, min max scaling, and min max of the states

# %%
dir_path = os.path.join(os.getcwd(), "Data/models")

# %%
# Defining the range of setpoints for data generation
setpoint_y = np.array([[0.002, -26.0],
                       [0.05, -16.0]])
u_min = np.array([300000.0, 100.0])
u_max = np.array([460000, 150.0])

system_data = load_and_prepare_system_data(steady_states=steady_states, setpoint_y=setpoint_y, u_min=u_min, u_max=u_max)

# %%
A_aug = system_data["A_aug"]
B_aug = system_data["B_aug"]
C_aug = system_data["C_aug"]

# %%
data_min = system_data["data_min"]
data_max = system_data["data_max"]

# %%
min_max_states = system_data["min_max_states"]

# %%
y_sp_scaled_deviation = system_data["y_sp_scaled_deviation"]

# %%
b_min = system_data["b_min"]
b_max = system_data["b_max"]

# %%
min_max_dict = system_data["min_max_dict"]

# %%
# Setpoints in deviation form
inputs_number = int(B_aug.shape[1])
y_sp_scenario = np.array([[0.013, -23.],
                         [0.018, -22.]])

y_sp_scenario = (apply_min_max(y_sp_scenario, data_min[inputs_number:], data_max[inputs_number:])
                 - apply_min_max(steady_states["y_ss"], data_min[inputs_number:], data_max[inputs_number:]))

n_tests = 200
set_points_len = 200
TEST_CYCLE = [False, False, False, False, False]
warm_start = 5
ACTOR_FREEZE = 4 * set_points_len
warm_start_plot = warm_start * 2 * set_points_len + ACTOR_FREEZE

# %% [markdown]
# ## Setting The hyperparameters for the TD3 Agent

# %%
from SACAgent.sac_agent import SACAgent
import torch

# %%
set_points_number = int(C_aug.shape[0])
STATE_DIM = int(A_aug.shape[0]) + set_points_number + inputs_number
ACTION_DIM = int(B_aug.shape[1])
n_outputs = C_aug.shape[0]
ACTOR_LAYER_SIZES = [512, 512, 512, 512, 512]
CRITIC_LAYER_SIZES = [512, 512, 512, 512, 512]
BUFFER_CAPACITY = 5_000_000
ACTOR_LR = 1e-4
CRITIC_LR = 1e-4
ALPHA_LR = 1e-4
GAMMA = 0.99
TAU = 0.005
MAX_ACTION = 1
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
BATCH_SIZE = 128

# %%
sac_agent = SACAgent(
    state_dim=STATE_DIM,
    action_dim=ACTION_DIM,
    actor_hidden=ACTOR_LAYER_SIZES,
    critic_hidden=CRITIC_LAYER_SIZES,
    gamma=GAMMA,
    actor_lr=ACTOR_LR,
    critic_lr=CRITIC_LR,
    alpha_lr=ALPHA_LR,
    batch_size=BATCH_SIZE,
    grad_clip_norm=10.0,
    init_alpha=0.2,
    learn_alpha=True,
    target_entropy=None,
    target_update="soft",
    tau=TAU,
    hard_update_interval=10_000,
    activation="relu",
    use_layernorm=False,
    dropout=0.0,
    max_action=MAX_ACTION,
    buffer_size=BUFFER_CAPACITY,
    use_per=False,
    device=DEVICE,
    use_adamw=True,
)

# %% [markdown]
# # Buffer filling

# %%
from BasicFunctions.td3_functions import filling_the_buffer, add_steady_state_samples

# %%
# MPC parameters
predict_h = 6
cont_h = 3
b1 = (b_min[0], b_max[0])
b2 = (b_min[1], b_max[1])
bnds = (b1, b2)*cont_h
cons = []
IC_opt = np.zeros(inputs_number*cont_h)
Q1_penalty = 1.
Q2_penalty = 1.
R1_penalty = 1.
R2_penalty = 1.
Q_penalty = np.array([[Q1_penalty, 0], [0, Q2_penalty]])
R_penalty = np.array([[R1_penalty, 0], [0, R2_penalty]])

# %%
MPC_obj = MpcSolver(A_aug, B_aug, C_aug,
                    Q1_penalty, Q2_penalty, R1_penalty, R2_penalty,
                    predict_h, cont_h)

# %%
steady_states_samples_number = 100000
mpc_pretrain_samples_numbers = BUFFER_CAPACITY - steady_states_samples_number

# %%
filling_the_buffer(
        min_max_dict,
        A_aug, B_aug, C_aug,
        MPC_obj,
        mpc_pretrain_samples_numbers,
        Q_penalty, R_penalty,
        sac_agent,
        IC_opt, bnds, cons, chunk_size= 100000)
# Out:
# Processing chunk 1/49
# Processing chunk 2/49
# Processing chunk 3/49
# Processing chunk 4/49
# Processing chunk 5/49
# Processing chunk 6/49
# Processing chunk 7/49
# Processing chunk 8/49
# Processing chunk 9/49
# Processing chunk 10/49
# Processing chunk 11/49
# Processing chunk 12/49
# Processing chunk 13/49
# Processing chunk 14/49
# Processing chunk 15/49
# Processing chunk 16/49
# Processing chunk 17/49
# Processing chunk 18/49
# Processing chunk 19/49
# Processing chunk 20/49
# Processing chunk 21/49
# Processing chunk 22/49
# Processing chunk 23/49
# Processing chunk 24/49
# Processing chunk 25/49
# Processing chunk 26/49
# Processing chunk 27/49
# Processing chunk 28/49
# Processing chunk 29/49
# Processing chunk 30/49
# Processing chunk 31/49
# Processing chunk 32/49
# Processing chunk 33/49
# Processing chunk 34/49
# Processing chunk 35/49
# Processing chunk 36/49
# Processing chunk 37/49
# Processing chunk 38/49
# Processing chunk 39/49
# Processing chunk 40/49
# Processing chunk 41/49
# Processing chunk 42/49
# Processing chunk 43/49
# Processing chunk 44/49
# Processing chunk 45/49
# Processing chunk 46/49
# Processing chunk 47/49
# Processing chunk 48/49
# Processing chunk 49/49
# Replay buffer has been filled with generated samples.

# %%
add_steady_state_samples(
        min_max_dict,
        A_aug, B_aug, C_aug,
        MPC_obj,
        steady_states_samples_number,
        Q_penalty, R_penalty,
        sac_agent,
        IC_opt, bnds, cons, chunk_size= 100000)
# Out:
# Processing chunk 1/1
# Replay buffer has been filled up with the steady_state values.

# %% [markdown]
# ## Pre training the Agent

# %%
for g in sac_agent.actor_optimizer.param_groups:
    g['lr'] = 1e-10
    print(g["lr"])
# for g in td3_agent.critic_optimizer.param_groups:
#     g['lr'] = 1e-6
#     print(g["lr"])
# Out:
# 1e-10

# %%
logs = sac_agent.pretrain_from_buffer(
    num_updates=1_500_000,
    log_interval=2000,
)
# Out:
# [SAC pretrain] it=2000  bc=1.2379e-08  q=9.3574e+00  alpha=0.000
# [SAC pretrain] it=4000  bc=1.3815e-08  q=9.1435e+00  alpha=0.000
# [SAC pretrain] it=6000  bc=1.5027e-08  q=8.9705e+00  alpha=0.000
# [SAC pretrain] it=8000  bc=1.4042e-08  q=7.5655e+00  alpha=0.000
# [SAC pretrain] it=10000  bc=1.6719e-08  q=7.7608e+00  alpha=0.000
# [SAC pretrain] it=12000  bc=1.4161e-08  q=9.3015e+00  alpha=0.000
# [SAC pretrain] it=14000  bc=1.6121e-08  q=9.6868e+00  alpha=0.000
# [SAC pretrain] it=16000  bc=1.5166e-08  q=1.0612e+01  alpha=0.000
# [SAC pretrain] it=18000  bc=1.4862e-08  q=8.7507e+00  alpha=0.000
# [SAC pretrain] it=20000  bc=1.2479e-08  q=9.3452e+00  alpha=0.000
# [SAC pretrain] it=22000  bc=1.2608e-08  q=1.0678e+01  alpha=0.000
# [SAC pretrain] it=24000  bc=1.1569e-08  q=9.2905e+00  alpha=0.000
# [SAC pretrain] it=26000  bc=1.8575e-08  q=8.4993e+00  alpha=0.000
# [SAC pretrain] it=28000  bc=1.3088e-08  q=9.4427e+00  alpha=0.000
# [SAC pretrain] it=30000  bc=1.8579e-08  q=1.0930e+01  alpha=0.000
# [SAC pretrain] it=32000  bc=1.4529e-08  q=1.0671e+01  alpha=0.000
# [SAC pretrain] it=34000  bc=1.7003e-08  q=9.8625e+00  alpha=0.000
# [SAC pretrain] it=36000  bc=1.4044e-08  q=1.0122e+01  alpha=0.000
# [SAC pretrain] it=38000  bc=1.3720e-08  q=9.3629e+00  alpha=0.000
# [SAC pretrain] it=40000  bc=1.6575e-08  q=1.0943e+01  alpha=0.000
# [SAC pretrain] it=42000  bc=1.2752e-08  q=1.1097e+01  alpha=0.000
# [SAC pretrain] it=44000  bc=1.6679e-08  q=1.0429e+01  alpha=0.000
# [SAC pretrain] it=46000  bc=1.3403e-08  q=9.4913e+00  alpha=0.000
# [SAC pretrain] it=48000  bc=1.0862e-08  q=1.2765e+01  alpha=0.000
# [SAC pretrain] it=50000  bc=1.9595e-08  q=1.1691e+01  alpha=0.000
# [SAC pretrain] it=52000  bc=1.5311e-08  q=1.0403e+01  alpha=0.000
# [SAC pretrain] it=54000  bc=1.4724e-08  q=9.4927e+00  alpha=0.000
# [SAC pretrain] it=56000  bc=1.6243e-08  q=1.0939e+01  alpha=0.000
# [SAC pretrain] it=58000  bc=1.3518e-08  q=1.1753e+01  alpha=0.000
# [SAC pretrain] it=60000  bc=1.7719e-08  q=9.3899e+00  alpha=0.000
# [SAC pretrain] it=62000  bc=1.7428e-08  q=9.6392e+00  alpha=0.000
# [SAC pretrain] it=64000  bc=1.3909e-08  q=1.0809e+01  alpha=0.000
# [SAC pretrain] it=66000  bc=1.3059e-08  q=9.7757e+00  alpha=0.000
# [SAC pretrain] it=68000  bc=1.4135e-08  q=9.4997e+00  alpha=0.000
# [SAC pretrain] it=70000  bc=1.9012e-08  q=1.1057e+01  alpha=0.000
# [SAC pretrain] it=72000  bc=2.2434e-08  q=1.0823e+01  alpha=0.000
# [SAC pretrain] it=74000  bc=1.3898e-08  q=8.3998e+00  alpha=0.000
# [SAC pretrain] it=76000  bc=1.2308e-08  q=9.7792e+00  alpha=0.000
# [SAC pretrain] it=78000  bc=1.9486e-08  q=1.1337e+01  alpha=0.000
# [SAC pretrain] it=80000  bc=1.4231e-08  q=1.0126e+01  alpha=0.000
# [SAC pretrain] it=82000  bc=1.6390e-08  q=9.2436e+00  alpha=0.000
# [SAC pretrain] it=84000  bc=1.3701e-08  q=1.1138e+01  alpha=0.000
# [SAC pretrain] it=86000  bc=1.5595e-08  q=1.1224e+01  alpha=0.000
# [SAC pretrain] it=88000  bc=1.2486e-08  q=8.7559e+00  alpha=0.000
# [SAC pretrain] it=90000  bc=1.5726e-08  q=9.1495e+00  alpha=0.000
# [SAC pretrain] it=92000  bc=1.5467e-08  q=9.0889e+00  alpha=0.000
# [SAC pretrain] it=94000  bc=1.6061e-08  q=8.4842e+00  alpha=0.000
# [SAC pretrain] it=96000  bc=2.1287e-08  q=8.8798e+00  alpha=0.000
# [SAC pretrain] it=98000  bc=1.3015e-08  q=1.0309e+01  alpha=0.000
# [SAC pretrain] it=100000  bc=1.7903e-08  q=8.2907e+00  alpha=0.000
# [SAC pretrain] it=102000  bc=1.5889e-08  q=1.1152e+01  alpha=0.000
# [SAC pretrain] it=104000  bc=1.9286e-08  q=8.5615e+00  alpha=0.000
# [SAC pretrain] it=106000  bc=1.6272e-08  q=1.0927e+01  alpha=0.000
# [SAC pretrain] it=108000  bc=1.5330e-08  q=8.0163e+00  alpha=0.000
# [SAC pretrain] it=110000  bc=1.2509e-08  q=8.5863e+00  alpha=0.000
# [SAC pretrain] it=112000  bc=1.3396e-08  q=9.6470e+00  alpha=0.000
# [SAC pretrain] it=114000  bc=1.3022e-08  q=8.3123e+00  alpha=0.000
# [SAC pretrain] it=116000  bc=1.7650e-08  q=9.9237e+00  alpha=0.000
# [SAC pretrain] it=118000  bc=1.1782e-08  q=8.4976e+00  alpha=0.000
# [SAC pretrain] it=120000  bc=1.4721e-08  q=9.4417e+00  alpha=0.000
# [SAC pretrain] it=122000  bc=1.1829e-08  q=7.3170e+00  alpha=0.000
# [SAC pretrain] it=124000  bc=1.3342e-08  q=9.9773e+00  alpha=0.000
# [SAC pretrain] it=126000  bc=2.3203e-08  q=8.0790e+00  alpha=0.000
# [SAC pretrain] it=128000  bc=1.7432e-08  q=8.0886e+00  alpha=0.000
# [SAC pretrain] it=130000  bc=1.2793e-08  q=7.5427e+00  alpha=0.000
# [SAC pretrain] it=132000  bc=1.6666e-08  q=8.7958e+00  alpha=0.000
# [SAC pretrain] it=134000  bc=1.6763e-08  q=7.4007e+00  alpha=0.000
# [SAC pretrain] it=136000  bc=1.6413e-08  q=7.9490e+00  alpha=0.000
# [SAC pretrain] it=138000  bc=1.3754e-08  q=7.0642e+00  alpha=0.000
# [SAC pretrain] it=140000  bc=1.6523e-08  q=8.0486e+00  alpha=0.000
# [SAC pretrain] it=142000  bc=1.4845e-08  q=7.5646e+00  alpha=0.000
# [SAC pretrain] it=144000  bc=1.6265e-08  q=7.5645e+00  alpha=0.000
# [SAC pretrain] it=146000  bc=1.4088e-08  q=8.1759e+00  alpha=0.000
# [SAC pretrain] it=148000  bc=1.5136e-08  q=8.5630e+00  alpha=0.000
# [SAC pretrain] it=150000  bc=1.1650e-08  q=7.9532e+00  alpha=0.000
# [SAC pretrain] it=152000  bc=1.5347e-08  q=8.2962e+00  alpha=0.000
# [SAC pretrain] it=154000  bc=1.6967e-08  q=8.0399e+00  alpha=0.000
# [SAC pretrain] it=156000  bc=1.1932e-08  q=6.5890e+00  alpha=0.000
# [SAC pretrain] it=158000  bc=1.2648e-08  q=6.8870e+00  alpha=0.000
# [SAC pretrain] it=160000  bc=1.8363e-08  q=8.9204e+00  alpha=0.000
# [SAC pretrain] it=162000  bc=1.4001e-08  q=8.0275e+00  alpha=0.000
# [SAC pretrain] it=164000  bc=1.6124e-08  q=8.5268e+00  alpha=0.000
# [SAC pretrain] it=166000  bc=1.6939e-08  q=8.5893e+00  alpha=0.000
# [SAC pretrain] it=168000  bc=1.6443e-08  q=7.5671e+00  alpha=0.000
# [SAC pretrain] it=170000  bc=1.2783e-08  q=7.1176e+00  alpha=0.000
# [SAC pretrain] it=172000  bc=1.3594e-08  q=7.2685e+00  alpha=0.000
# [SAC pretrain] it=174000  bc=1.5924e-08  q=7.4890e+00  alpha=0.000
# [SAC pretrain] it=176000  bc=1.7094e-08  q=7.9864e+00  alpha=0.000
# [SAC pretrain] it=178000  bc=1.3592e-08  q=8.0722e+00  alpha=0.000
# [SAC pretrain] it=180000  bc=1.3498e-08  q=7.7465e+00  alpha=0.000
# [SAC pretrain] it=182000  bc=1.3025e-08  q=8.2121e+00  alpha=0.000
# [SAC pretrain] it=184000  bc=1.8691e-08  q=8.2786e+00  alpha=0.000
# [SAC pretrain] it=186000  bc=1.3582e-08  q=7.1886e+00  alpha=0.000
# [SAC pretrain] it=188000  bc=1.9954e-08  q=7.4044e+00  alpha=0.000
# [SAC pretrain] it=190000  bc=2.0938e-08  q=7.7123e+00  alpha=0.000
# [SAC pretrain] it=192000  bc=1.7244e-08  q=7.5006e+00  alpha=0.000
# [SAC pretrain] it=194000  bc=1.3082e-08  q=8.8624e+00  alpha=0.000
# [SAC pretrain] it=196000  bc=1.2590e-08  q=7.4124e+00  alpha=0.000
# [SAC pretrain] it=198000  bc=1.5047e-08  q=8.9930e+00  alpha=0.000
# [SAC pretrain] it=200000  bc=1.6530e-08  q=8.6296e+00  alpha=0.000
# [SAC pretrain] it=202000  bc=1.2404e-08  q=6.8460e+00  alpha=0.000
# [SAC pretrain] it=204000  bc=1.6910e-08  q=9.5239e+00  alpha=0.000
# [SAC pretrain] it=206000  bc=1.5100e-08  q=7.2422e+00  alpha=0.000
# [SAC pretrain] it=208000  bc=1.1193e-08  q=9.7072e+00  alpha=0.000
# [SAC pretrain] it=210000  bc=2.0976e-08  q=8.8544e+00  alpha=0.000
# [SAC pretrain] it=212000  bc=1.3923e-08  q=8.2649e+00  alpha=0.000
# [SAC pretrain] it=214000  bc=2.0639e-08  q=6.5976e+00  alpha=0.000
# [SAC pretrain] it=216000  bc=1.7771e-08  q=8.4792e+00  alpha=0.000
# [SAC pretrain] it=218000  bc=1.5570e-08  q=8.5324e+00  alpha=0.000
# [SAC pretrain] it=220000  bc=2.0347e-08  q=6.6611e+00  alpha=0.000
# [SAC pretrain] it=222000  bc=1.0621e-08  q=6.4460e+00  alpha=0.000
# [SAC pretrain] it=224000  bc=1.7720e-08  q=6.6173e+00  alpha=0.000
# [SAC pretrain] it=226000  bc=1.7296e-08  q=9.0294e+00  alpha=0.000
# [SAC pretrain] it=228000  bc=1.3523e-08  q=7.1959e+00  alpha=0.000
# [SAC pretrain] it=230000  bc=1.6689e-08  q=8.2543e+00  alpha=0.000
# [SAC pretrain] it=232000  bc=2.0759e-08  q=8.8892e+00  alpha=0.000
# [SAC pretrain] it=234000  bc=1.8570e-08  q=7.8045e+00  alpha=0.000
# [SAC pretrain] it=236000  bc=1.3833e-08  q=7.3744e+00  alpha=0.000
# [SAC pretrain] it=238000  bc=1.4626e-08  q=6.7524e+00  alpha=0.000
# [SAC pretrain] it=240000  bc=1.8682e-08  q=7.2791e+00  alpha=0.000
# [SAC pretrain] it=242000  bc=1.1535e-08  q=8.0089e+00  alpha=0.000
# [SAC pretrain] it=244000  bc=1.9822e-08  q=8.6972e+00  alpha=0.000
# [SAC pretrain] it=246000  bc=1.5267e-08  q=7.4571e+00  alpha=0.000
# [SAC pretrain] it=248000  bc=1.4240e-08  q=8.5306e+00  alpha=0.000
# [SAC pretrain] it=250000  bc=1.5240e-08  q=7.2464e+00  alpha=0.000
# [SAC pretrain] it=252000  bc=2.1390e-08  q=8.1239e+00  alpha=0.000
# [SAC pretrain] it=254000  bc=1.3636e-08  q=8.5572e+00  alpha=0.000
# [SAC pretrain] it=256000  bc=1.3825e-08  q=8.6352e+00  alpha=0.000
# [SAC pretrain] it=258000  bc=1.5129e-08  q=7.3271e+00  alpha=0.000
# [SAC pretrain] it=260000  bc=1.5540e-08  q=8.8465e+00  alpha=0.000
# [SAC pretrain] it=262000  bc=1.5764e-08  q=8.9376e+00  alpha=0.000
# [SAC pretrain] it=264000  bc=1.8568e-08  q=8.3946e+00  alpha=0.000
# [SAC pretrain] it=266000  bc=1.6621e-08  q=7.5234e+00  alpha=0.000
# [SAC pretrain] it=268000  bc=1.7412e-08  q=7.9523e+00  alpha=0.000
# [SAC pretrain] it=270000  bc=1.3178e-08  q=6.7028e+00  alpha=0.000
# [SAC pretrain] it=272000  bc=1.2800e-08  q=8.7034e+00  alpha=0.000
# [SAC pretrain] it=274000  bc=1.6768e-08  q=9.0020e+00  alpha=0.000
# [SAC pretrain] it=276000  bc=1.5361e-08  q=7.2771e+00  alpha=0.000
# [SAC pretrain] it=278000  bc=1.8575e-08  q=7.5247e+00  alpha=0.000
# [SAC pretrain] it=280000  bc=1.4847e-08  q=8.3425e+00  alpha=0.000
# [SAC pretrain] it=282000  bc=1.7134e-08  q=7.5175e+00  alpha=0.000
# [SAC pretrain] it=284000  bc=1.4235e-08  q=1.0053e+01  alpha=0.000
# [SAC pretrain] it=286000  bc=1.3979e-08  q=8.4467e+00  alpha=0.000
# [SAC pretrain] it=288000  bc=1.2764e-08  q=6.9973e+00  alpha=0.000
# [SAC pretrain] it=290000  bc=1.5129e-08  q=7.7971e+00  alpha=0.000
# [SAC pretrain] it=292000  bc=1.5542e-08  q=8.4322e+00  alpha=0.000
# [SAC pretrain] it=294000  bc=1.6740e-08  q=7.7171e+00  alpha=0.000
# [SAC pretrain] it=296000  bc=1.4049e-08  q=8.0327e+00  alpha=0.000
# [SAC pretrain] it=298000  bc=1.3918e-08  q=7.9891e+00  alpha=0.000
# [SAC pretrain] it=300000  bc=1.4671e-08  q=6.6215e+00  alpha=0.000
# [SAC pretrain] it=302000  bc=1.8043e-08  q=7.3905e+00  alpha=0.000
# [SAC pretrain] it=304000  bc=1.9177e-08  q=7.6231e+00  alpha=0.000
# [SAC pretrain] it=306000  bc=1.3471e-08  q=7.1082e+00  alpha=0.000
# [SAC pretrain] it=308000  bc=1.3461e-08  q=8.3949e+00  alpha=0.000
# [SAC pretrain] it=310000  bc=1.3967e-08  q=8.0454e+00  alpha=0.000
# [SAC pretrain] it=312000  bc=1.1527e-08  q=7.7012e+00  alpha=0.000
# [SAC pretrain] it=314000  bc=1.0982e-08  q=6.7763e+00  alpha=0.000
# [SAC pretrain] it=316000  bc=1.4328e-08  q=7.3382e+00  alpha=0.000
# [SAC pretrain] it=318000  bc=1.5691e-08  q=7.0043e+00  alpha=0.000
# [SAC pretrain] it=320000  bc=1.3608e-08  q=7.9918e+00  alpha=0.000
# [SAC pretrain] it=322000  bc=2.0422e-08  q=8.2516e+00  alpha=0.000
# [SAC pretrain] it=324000  bc=1.5803e-08  q=7.4493e+00  alpha=0.000
# [SAC pretrain] it=326000  bc=1.2730e-08  q=6.9888e+00  alpha=0.000
# [SAC pretrain] it=328000  bc=1.5184e-08  q=6.7465e+00  alpha=0.000
# [SAC pretrain] it=330000  bc=1.0748e-08  q=8.2469e+00  alpha=0.000
# [SAC pretrain] it=332000  bc=1.9474e-08  q=9.2857e+00  alpha=0.000
# [SAC pretrain] it=334000  bc=1.2887e-08  q=7.0249e+00  alpha=0.000
# [SAC pretrain] it=336000  bc=1.3159e-08  q=8.7480e+00  alpha=0.000
# [SAC pretrain] it=338000  bc=2.0425e-08  q=9.7976e+00  alpha=0.000
# [SAC pretrain] it=340000  bc=1.2558e-08  q=7.6912e+00  alpha=0.000
# [SAC pretrain] it=342000  bc=1.5337e-08  q=8.1566e+00  alpha=0.000
# [SAC pretrain] it=344000  bc=1.8224e-08  q=8.0104e+00  alpha=0.000
# [SAC pretrain] it=346000  bc=1.3698e-08  q=8.3288e+00  alpha=0.000
# [SAC pretrain] it=348000  bc=1.4951e-08  q=8.1165e+00  alpha=0.000
# [SAC pretrain] it=350000  bc=1.5003e-08  q=9.2597e+00  alpha=0.000
# [SAC pretrain] it=352000  bc=1.3475e-08  q=7.4726e+00  alpha=0.000
# [SAC pretrain] it=354000  bc=1.4956e-08  q=7.1850e+00  alpha=0.000
# [SAC pretrain] it=356000  bc=1.2525e-08  q=7.7355e+00  alpha=0.000
# [SAC pretrain] it=358000  bc=1.3102e-08  q=9.3274e+00  alpha=0.000
# [SAC pretrain] it=360000  bc=1.7043e-08  q=7.9868e+00  alpha=0.000
# [SAC pretrain] it=362000  bc=1.0990e-08  q=8.0456e+00  alpha=0.000
# [SAC pretrain] it=364000  bc=1.1458e-08  q=7.2196e+00  alpha=0.000
# [SAC pretrain] it=366000  bc=1.8141e-08  q=8.2617e+00  alpha=0.000
# [SAC pretrain] it=368000  bc=1.4339e-08  q=9.0591e+00  alpha=0.000
# [SAC pretrain] it=370000  bc=1.5543e-08  q=7.9549e+00  alpha=0.000
# [SAC pretrain] it=372000  bc=1.3436e-08  q=8.4043e+00  alpha=0.000
# [SAC pretrain] it=374000  bc=1.6429e-08  q=8.5467e+00  alpha=0.000
# [SAC pretrain] it=376000  bc=2.1249e-08  q=7.8603e+00  alpha=0.000
# [SAC pretrain] it=378000  bc=1.7495e-08  q=9.5077e+00  alpha=0.000
# [SAC pretrain] it=380000  bc=1.4466e-08  q=7.2560e+00  alpha=0.000
# [SAC pretrain] it=382000  bc=1.2589e-08  q=9.3724e+00  alpha=0.000
# [SAC pretrain] it=384000  bc=1.5806e-08  q=9.5738e+00  alpha=0.000
# [SAC pretrain] it=386000  bc=1.6715e-08  q=9.5788e+00  alpha=0.000
# [SAC pretrain] it=388000  bc=1.3015e-08  q=9.9233e+00  alpha=0.000
# [SAC pretrain] it=390000  bc=1.8504e-08  q=8.2806e+00  alpha=0.000
# [SAC pretrain] it=392000  bc=1.7462e-08  q=8.9617e+00  alpha=0.000
# [SAC pretrain] it=394000  bc=1.4136e-08  q=7.9436e+00  alpha=0.000
# [SAC pretrain] it=396000  bc=1.4696e-08  q=8.8867e+00  alpha=0.000
# [SAC pretrain] it=398000  bc=1.6255e-08  q=8.1914e+00  alpha=0.000
# [SAC pretrain] it=400000  bc=1.8555e-08  q=9.2122e+00  alpha=0.000
# [SAC pretrain] it=402000  bc=1.6235e-08  q=7.8118e+00  alpha=0.000
# [SAC pretrain] it=404000  bc=1.0507e-08  q=8.2912e+00  alpha=0.000
# [SAC pretrain] it=406000  bc=1.6303e-08  q=9.3626e+00  alpha=0.000
# [SAC pretrain] it=408000  bc=1.6158e-08  q=7.1995e+00  alpha=0.000
# [SAC pretrain] it=410000  bc=1.7002e-08  q=7.9557e+00  alpha=0.000
# [SAC pretrain] it=412000  bc=1.4500e-08  q=8.3907e+00  alpha=0.000
# [SAC pretrain] it=414000  bc=1.4746e-08  q=8.6486e+00  alpha=0.000
# [SAC pretrain] it=416000  bc=1.4416e-08  q=7.3897e+00  alpha=0.000
# [SAC pretrain] it=418000  bc=1.5038e-08  q=8.6645e+00  alpha=0.000
# [SAC pretrain] it=420000  bc=1.5905e-08  q=8.3521e+00  alpha=0.000
# [SAC pretrain] it=422000  bc=1.2115e-08  q=9.4061e+00  alpha=0.000
# [SAC pretrain] it=424000  bc=1.2614e-08  q=8.4213e+00  alpha=0.000
# [SAC pretrain] it=426000  bc=1.4068e-08  q=8.9685e+00  alpha=0.000
# [SAC pretrain] it=428000  bc=1.5165e-08  q=7.6662e+00  alpha=0.000
# [SAC pretrain] it=430000  bc=1.4095e-08  q=7.5537e+00  alpha=0.000
# [SAC pretrain] it=432000  bc=1.2779e-08  q=7.9680e+00  alpha=0.000
# [SAC pretrain] it=434000  bc=1.3204e-08  q=8.0198e+00  alpha=0.000
# [SAC pretrain] it=436000  bc=1.6195e-08  q=9.6561e+00  alpha=0.000
# [SAC pretrain] it=438000  bc=1.6760e-08  q=6.0801e+00  alpha=0.000
# [SAC pretrain] it=440000  bc=4.0391e-08  q=9.4719e+00  alpha=0.000
# [SAC pretrain] it=442000  bc=1.4834e-08  q=7.8337e+00  alpha=0.000
# [SAC pretrain] it=444000  bc=1.1614e-08  q=8.9499e+00  alpha=0.000
# [SAC pretrain] it=446000  bc=1.3549e-08  q=9.5424e+00  alpha=0.000
# [SAC pretrain] it=448000  bc=1.2726e-08  q=1.1214e+01  alpha=0.000
# [SAC pretrain] it=450000  bc=1.2943e-08  q=9.7914e+00  alpha=0.000
# [SAC pretrain] it=452000  bc=1.3750e-08  q=8.9936e+00  alpha=0.000
# [SAC pretrain] it=454000  bc=1.5795e-08  q=9.0089e+00  alpha=0.000
# [SAC pretrain] it=456000  bc=1.8762e-08  q=7.1271e+00  alpha=0.000
# [SAC pretrain] it=458000  bc=1.6239e-08  q=6.9599e+00  alpha=0.000
# [SAC pretrain] it=460000  bc=1.3655e-08  q=7.8991e+00  alpha=0.000
# [SAC pretrain] it=462000  bc=1.7863e-08  q=8.5852e+00  alpha=0.000
# [SAC pretrain] it=464000  bc=1.4322e-08  q=1.0665e+01  alpha=0.000
# [SAC pretrain] it=466000  bc=1.2541e-08  q=8.2868e+00  alpha=0.000
# [SAC pretrain] it=468000  bc=2.0394e-08  q=7.9728e+00  alpha=0.000
# [SAC pretrain] it=470000  bc=1.1521e-08  q=7.9620e+00  alpha=0.000
# [SAC pretrain] it=472000  bc=1.5531e-08  q=8.6759e+00  alpha=0.000
# [SAC pretrain] it=474000  bc=1.5080e-08  q=8.4183e+00  alpha=0.000
# [SAC pretrain] it=476000  bc=1.4390e-08  q=9.5167e+00  alpha=0.000
# [SAC pretrain] it=478000  bc=2.0202e-08  q=7.6239e+00  alpha=0.000
# [SAC pretrain] it=480000  bc=1.3633e-08  q=1.0383e+01  alpha=0.000
# [SAC pretrain] it=482000  bc=1.4196e-08  q=7.7152e+00  alpha=0.000
# [SAC pretrain] it=484000  bc=1.3651e-08  q=9.4000e+00  alpha=0.000
# [SAC pretrain] it=486000  bc=1.8540e-08  q=9.0991e+00  alpha=0.000
# [SAC pretrain] it=488000  bc=1.2458e-08  q=8.6867e+00  alpha=0.000
# [SAC pretrain] it=490000  bc=2.2101e-08  q=9.3629e+00  alpha=0.000
# [SAC pretrain] it=492000  bc=1.8876e-08  q=1.0819e+01  alpha=0.000
# [SAC pretrain] it=494000  bc=1.2713e-08  q=8.4122e+00  alpha=0.000
# [SAC pretrain] it=496000  bc=1.0432e-08  q=9.5519e+00  alpha=0.000
# [SAC pretrain] it=498000  bc=1.2954e-08  q=9.0932e+00  alpha=0.000
# [SAC pretrain] it=500000  bc=1.0787e-08  q=1.1152e+01  alpha=0.000
# [SAC pretrain] it=502000  bc=1.4151e-08  q=1.0452e+01  alpha=0.000
# [SAC pretrain] it=504000  bc=1.6323e-08  q=1.0764e+01  alpha=0.000
# [SAC pretrain] it=506000  bc=1.7157e-08  q=1.0187e+01  alpha=0.000
# [SAC pretrain] it=508000  bc=1.3751e-08  q=9.6636e+00  alpha=0.000
# [SAC pretrain] it=510000  bc=1.1957e-08  q=8.1988e+00  alpha=0.000
# [SAC pretrain] it=512000  bc=1.4962e-08  q=7.9266e+00  alpha=0.000
# [SAC pretrain] it=514000  bc=1.6902e-08  q=8.0645e+00  alpha=0.000
# [SAC pretrain] it=516000  bc=1.6672e-08  q=8.8684e+00  alpha=0.000
# [SAC pretrain] it=518000  bc=1.1568e-08  q=9.5284e+00  alpha=0.000
# [SAC pretrain] it=520000  bc=1.4879e-08  q=8.9475e+00  alpha=0.000
# [SAC pretrain] it=522000  bc=1.2477e-08  q=1.0164e+01  alpha=0.000
# [SAC pretrain] it=524000  bc=2.0195e-08  q=9.9503e+00  alpha=0.000
# [SAC pretrain] it=526000  bc=1.5179e-08  q=9.1904e+00  alpha=0.000
# [SAC pretrain] it=528000  bc=1.4896e-08  q=7.8457e+00  alpha=0.000
# [SAC pretrain] it=530000  bc=1.4422e-08  q=9.4288e+00  alpha=0.000
# [SAC pretrain] it=532000  bc=1.8944e-08  q=1.0320e+01  alpha=0.000
# [SAC pretrain] it=534000  bc=1.3890e-08  q=1.0074e+01  alpha=0.000
# [SAC pretrain] it=536000  bc=1.2992e-08  q=7.2443e+00  alpha=0.000
# [SAC pretrain] it=538000  bc=2.3403e-08  q=8.7759e+00  alpha=0.000
# [SAC pretrain] it=540000  bc=1.8029e-08  q=7.8713e+00  alpha=0.000
# [SAC pretrain] it=542000  bc=1.6913e-08  q=1.1138e+01  alpha=0.000
# [SAC pretrain] it=544000  bc=1.4351e-08  q=8.0445e+00  alpha=0.000
# [SAC pretrain] it=546000  bc=1.9924e-08  q=8.7000e+00  alpha=0.000
# [SAC pretrain] it=548000  bc=1.9467e-08  q=1.1682e+01  alpha=0.000
# [SAC pretrain] it=550000  bc=1.2694e-08  q=1.0462e+01  alpha=0.000
# [SAC pretrain] it=552000  bc=1.6386e-08  q=1.0218e+01  alpha=0.000
# [SAC pretrain] it=554000  bc=1.4406e-08  q=8.5740e+00  alpha=0.000
# [SAC pretrain] it=556000  bc=1.3003e-08  q=8.6340e+00  alpha=0.000
# [SAC pretrain] it=558000  bc=1.6583e-08  q=7.7482e+00  alpha=0.000
# [SAC pretrain] it=560000  bc=2.2081e-08  q=8.7767e+00  alpha=0.000
# [SAC pretrain] it=562000  bc=1.4073e-08  q=9.4124e+00  alpha=0.000
# [SAC pretrain] it=564000  bc=1.5388e-08  q=1.1211e+01  alpha=0.000
# [SAC pretrain] it=566000  bc=1.0503e-08  q=1.0066e+01  alpha=0.000
# [SAC pretrain] it=568000  bc=1.2710e-08  q=1.0371e+01  alpha=0.000
# [SAC pretrain] it=570000  bc=9.7048e-09  q=9.5666e+00  alpha=0.000
# [SAC pretrain] it=572000  bc=2.0539e-08  q=9.7756e+00  alpha=0.000
# [SAC pretrain] it=574000  bc=1.1738e-08  q=9.9247e+00  alpha=0.000
# [SAC pretrain] it=576000  bc=1.4738e-08  q=9.1419e+00  alpha=0.000
# [SAC pretrain] it=578000  bc=1.4159e-08  q=9.9093e+00  alpha=0.000
# [SAC pretrain] it=580000  bc=1.7311e-08  q=8.2371e+00  alpha=0.000
# [SAC pretrain] it=582000  bc=1.4904e-08  q=1.0466e+01  alpha=0.000
# [SAC pretrain] it=584000  bc=1.3052e-08  q=9.0773e+00  alpha=0.000
# [SAC pretrain] it=586000  bc=1.3987e-08  q=7.7040e+00  alpha=0.000
# [SAC pretrain] it=588000  bc=1.4617e-08  q=8.9869e+00  alpha=0.000
# [SAC pretrain] it=590000  bc=1.8089e-08  q=8.2188e+00  alpha=0.000
# [SAC pretrain] it=592000  bc=1.4988e-08  q=7.4135e+00  alpha=0.000
# [SAC pretrain] it=594000  bc=1.2300e-08  q=8.7701e+00  alpha=0.000
# [SAC pretrain] it=596000  bc=1.2035e-08  q=6.4627e+00  alpha=0.000
# [SAC pretrain] it=598000  bc=1.3789e-08  q=7.7017e+00  alpha=0.000
# [SAC pretrain] it=600000  bc=2.1838e-08  q=7.7391e+00  alpha=0.000
# [SAC pretrain] it=602000  bc=1.6373e-08  q=7.5205e+00  alpha=0.000
# [SAC pretrain] it=604000  bc=1.2247e-08  q=7.7716e+00  alpha=0.000
# [SAC pretrain] it=606000  bc=1.3521e-08  q=7.6919e+00  alpha=0.000
# [SAC pretrain] it=608000  bc=2.3689e-08  q=7.2553e+00  alpha=0.000
# [SAC pretrain] it=610000  bc=1.2655e-08  q=5.9974e+00  alpha=0.000
# [SAC pretrain] it=612000  bc=1.6140e-08  q=7.8623e+00  alpha=0.000
# [SAC pretrain] it=614000  bc=1.3895e-08  q=7.8886e+00  alpha=0.000
# [SAC pretrain] it=616000  bc=2.1296e-08  q=7.9445e+00  alpha=0.000
# [SAC pretrain] it=618000  bc=1.4533e-08  q=7.6069e+00  alpha=0.000
# [SAC pretrain] it=620000  bc=1.3450e-08  q=7.1612e+00  alpha=0.000
# [SAC pretrain] it=622000  bc=1.8457e-08  q=7.4567e+00  alpha=0.000
# [SAC pretrain] it=624000  bc=1.8233e-08  q=7.7524e+00  alpha=0.000
# [SAC pretrain] it=626000  bc=2.0527e-08  q=8.7968e+00  alpha=0.000
# [SAC pretrain] it=628000  bc=1.4034e-08  q=8.0964e+00  alpha=0.000
# [SAC pretrain] it=630000  bc=1.3165e-08  q=8.6396e+00  alpha=0.000
# [SAC pretrain] it=632000  bc=1.3242e-08  q=8.9825e+00  alpha=0.000
# [SAC pretrain] it=634000  bc=1.6484e-08  q=8.8736e+00  alpha=0.000
# [SAC pretrain] it=636000  bc=1.4774e-08  q=7.8766e+00  alpha=0.000
# [SAC pretrain] it=638000  bc=1.7733e-08  q=9.3398e+00  alpha=0.000
# [SAC pretrain] it=640000  bc=1.3690e-08  q=8.2488e+00  alpha=0.000
# [SAC pretrain] it=642000  bc=1.3999e-08  q=8.7782e+00  alpha=0.000
# [SAC pretrain] it=644000  bc=2.3984e-08  q=8.9444e+00  alpha=0.000
# [SAC pretrain] it=646000  bc=1.2007e-08  q=9.5723e+00  alpha=0.000
# [SAC pretrain] it=648000  bc=1.5809e-08  q=8.3130e+00  alpha=0.000
# [SAC pretrain] it=650000  bc=1.1923e-08  q=1.0178e+01  alpha=0.000
# [SAC pretrain] it=652000  bc=1.3043e-08  q=1.0067e+01  alpha=0.000
# [SAC pretrain] it=654000  bc=1.2529e-08  q=9.7758e+00  alpha=0.000
# [SAC pretrain] it=656000  bc=1.1945e-08  q=9.9488e+00  alpha=0.000
# [SAC pretrain] it=658000  bc=1.1435e-08  q=9.3379e+00  alpha=0.000
# [SAC pretrain] it=660000  bc=1.4454e-08  q=9.9782e+00  alpha=0.000
# [SAC pretrain] it=662000  bc=1.7102e-08  q=1.0450e+01  alpha=0.000
# [SAC pretrain] it=664000  bc=1.5228e-08  q=9.2235e+00  alpha=0.000
# [SAC pretrain] it=666000  bc=1.2702e-08  q=1.0787e+01  alpha=0.000
# [SAC pretrain] it=668000  bc=1.3810e-08  q=9.1876e+00  alpha=0.000
# [SAC pretrain] it=670000  bc=1.5598e-08  q=1.0165e+01  alpha=0.000
# [SAC pretrain] it=672000  bc=1.3602e-08  q=1.0381e+01  alpha=0.000
# [SAC pretrain] it=674000  bc=1.7886e-08  q=1.0058e+01  alpha=0.000
# [SAC pretrain] it=676000  bc=1.9057e-08  q=9.9218e+00  alpha=0.000
# [SAC pretrain] it=678000  bc=1.5430e-08  q=1.2045e+01  alpha=0.000
# [SAC pretrain] it=680000  bc=1.2446e-08  q=1.0192e+01  alpha=0.000
# [SAC pretrain] it=682000  bc=1.2669e-08  q=9.2048e+00  alpha=0.000
# [SAC pretrain] it=684000  bc=1.3137e-08  q=9.5198e+00  alpha=0.000
# [SAC pretrain] it=686000  bc=1.4650e-08  q=1.1389e+01  alpha=0.000
# [SAC pretrain] it=688000  bc=1.6663e-08  q=9.3535e+00  alpha=0.000
# [SAC pretrain] it=690000  bc=1.1169e-08  q=9.1713e+00  alpha=0.000
# [SAC pretrain] it=692000  bc=1.5224e-08  q=9.4688e+00  alpha=0.000
# [SAC pretrain] it=694000  bc=1.7156e-08  q=1.0040e+01  alpha=0.000
# [SAC pretrain] it=696000  bc=1.3526e-08  q=1.0845e+01  alpha=0.000
# [SAC pretrain] it=698000  bc=1.6613e-08  q=1.0223e+01  alpha=0.000
# [SAC pretrain] it=700000  bc=1.5060e-08  q=1.0596e+01  alpha=0.000
# [SAC pretrain] it=702000  bc=1.4611e-08  q=9.0846e+00  alpha=0.000
# [SAC pretrain] it=704000  bc=1.1150e-08  q=9.7239e+00  alpha=0.000
# [SAC pretrain] it=706000  bc=1.4841e-08  q=9.7662e+00  alpha=0.000
# [SAC pretrain] it=708000  bc=1.5704e-08  q=9.0571e+00  alpha=0.000
# [SAC pretrain] it=710000  bc=1.7560e-08  q=9.0165e+00  alpha=0.000
# [SAC pretrain] it=712000  bc=1.3346e-08  q=9.5270e+00  alpha=0.000
# [SAC pretrain] it=714000  bc=1.6916e-08  q=9.5870e+00  alpha=0.000
# [SAC pretrain] it=716000  bc=1.1207e-08  q=1.0936e+01  alpha=0.000
# [SAC pretrain] it=718000  bc=1.8540e-08  q=9.0268e+00  alpha=0.000
# [SAC pretrain] it=720000  bc=1.7791e-08  q=8.5547e+00  alpha=0.000
# [SAC pretrain] it=722000  bc=1.3304e-08  q=1.0021e+01  alpha=0.000
# [SAC pretrain] it=724000  bc=1.3210e-08  q=8.2085e+00  alpha=0.000
# [SAC pretrain] it=726000  bc=1.4036e-08  q=1.0550e+01  alpha=0.000
# [SAC pretrain] it=728000  bc=1.4881e-08  q=1.0993e+01  alpha=0.000
# [SAC pretrain] it=730000  bc=1.6891e-08  q=9.8406e+00  alpha=0.000
# [SAC pretrain] it=732000  bc=1.6094e-08  q=8.0107e+00  alpha=0.000
# [SAC pretrain] it=734000  bc=1.8185e-08  q=9.8328e+00  alpha=0.000
# [SAC pretrain] it=736000  bc=1.9013e-08  q=1.0889e+01  alpha=0.000
# [SAC pretrain] it=738000  bc=1.5264e-08  q=8.7575e+00  alpha=0.000
# [SAC pretrain] it=740000  bc=1.2070e-08  q=8.9735e+00  alpha=0.000
# [SAC pretrain] it=742000  bc=1.8034e-08  q=8.3115e+00  alpha=0.000
# [SAC pretrain] it=744000  bc=2.3420e-08  q=9.1295e+00  alpha=0.000
# [SAC pretrain] it=746000  bc=1.2919e-08  q=8.7592e+00  alpha=0.000
# [SAC pretrain] it=748000  bc=1.7766e-08  q=9.4131e+00  alpha=0.000
# [SAC pretrain] it=750000  bc=1.5861e-08  q=8.4979e+00  alpha=0.000
# [SAC pretrain] it=752000  bc=1.8888e-08  q=8.1899e+00  alpha=0.000
# [SAC pretrain] it=754000  bc=1.7192e-08  q=7.4718e+00  alpha=0.000
# [SAC pretrain] it=756000  bc=1.7179e-08  q=8.9712e+00  alpha=0.000
# [SAC pretrain] it=758000  bc=1.6527e-08  q=8.0886e+00  alpha=0.000
# [SAC pretrain] it=760000  bc=1.2560e-08  q=8.9977e+00  alpha=0.000
# [SAC pretrain] it=762000  bc=1.4220e-08  q=7.3438e+00  alpha=0.000
# [SAC pretrain] it=764000  bc=1.3601e-08  q=8.0018e+00  alpha=0.000
# [SAC pretrain] it=766000  bc=1.6061e-08  q=7.7250e+00  alpha=0.000
# [SAC pretrain] it=768000  bc=1.2854e-08  q=8.5003e+00  alpha=0.000
# [SAC pretrain] it=770000  bc=1.6550e-08  q=8.3570e+00  alpha=0.000
# [SAC pretrain] it=772000  bc=1.7476e-08  q=7.9668e+00  alpha=0.000
# [SAC pretrain] it=774000  bc=1.5556e-08  q=9.2179e+00  alpha=0.000
# [SAC pretrain] it=776000  bc=1.8835e-08  q=9.2136e+00  alpha=0.000
# [SAC pretrain] it=778000  bc=1.1927e-08  q=8.9996e+00  alpha=0.000
# [SAC pretrain] it=780000  bc=1.5399e-08  q=8.0579e+00  alpha=0.000
# [SAC pretrain] it=782000  bc=1.6946e-08  q=1.0411e+01  alpha=0.000
# [SAC pretrain] it=784000  bc=1.8244e-08  q=9.3459e+00  alpha=0.000
# [SAC pretrain] it=786000  bc=1.4706e-08  q=9.9325e+00  alpha=0.000
# [SAC pretrain] it=788000  bc=2.0477e-08  q=8.9646e+00  alpha=0.000
# [SAC pretrain] it=790000  bc=1.5258e-08  q=8.0090e+00  alpha=0.000
# [SAC pretrain] it=792000  bc=1.3616e-08  q=9.1965e+00  alpha=0.000
# [SAC pretrain] it=794000  bc=1.3790e-08  q=1.0027e+01  alpha=0.000
# [SAC pretrain] it=796000  bc=1.7132e-08  q=8.9074e+00  alpha=0.000
# [SAC pretrain] it=798000  bc=1.8707e-08  q=8.8190e+00  alpha=0.000
# [SAC pretrain] it=800000  bc=1.4498e-08  q=9.6506e+00  alpha=0.000
# [SAC pretrain] it=802000  bc=1.2404e-08  q=8.1758e+00  alpha=0.000
# [SAC pretrain] it=804000  bc=1.5520e-08  q=1.0336e+01  alpha=0.000
# [SAC pretrain] it=806000  bc=1.5409e-08  q=8.5934e+00  alpha=0.000
# [SAC pretrain] it=808000  bc=1.4083e-08  q=1.1002e+01  alpha=0.000
# [SAC pretrain] it=810000  bc=2.0255e-08  q=1.0532e+01  alpha=0.000
# [SAC pretrain] it=812000  bc=1.4845e-08  q=1.2044e+01  alpha=0.000
# [SAC pretrain] it=814000  bc=1.4339e-08  q=1.0634e+01  alpha=0.000
# [SAC pretrain] it=816000  bc=1.5876e-08  q=1.0026e+01  alpha=0.000
# [SAC pretrain] it=818000  bc=1.2281e-08  q=9.2835e+00  alpha=0.000
# [SAC pretrain] it=820000  bc=1.2810e-08  q=9.2890e+00  alpha=0.000
# [SAC pretrain] it=822000  bc=1.2895e-08  q=9.0457e+00  alpha=0.000
# [SAC pretrain] it=824000  bc=1.2271e-08  q=9.5288e+00  alpha=0.000
# [SAC pretrain] it=826000  bc=1.7352e-08  q=9.0191e+00  alpha=0.000
# [SAC pretrain] it=828000  bc=9.6623e-09  q=9.1120e+00  alpha=0.000
# [SAC pretrain] it=830000  bc=1.2227e-08  q=9.0733e+00  alpha=0.000
# [SAC pretrain] it=832000  bc=1.0922e-08  q=8.4409e+00  alpha=0.000
# [SAC pretrain] it=834000  bc=1.5085e-08  q=9.7782e+00  alpha=0.000
# [SAC pretrain] it=836000  bc=1.4895e-08  q=8.6324e+00  alpha=0.000
# [SAC pretrain] it=838000  bc=1.4331e-08  q=8.3039e+00  alpha=0.000
# [SAC pretrain] it=840000  bc=1.9773e-08  q=8.1820e+00  alpha=0.000
# [SAC pretrain] it=842000  bc=1.5513e-08  q=1.0248e+01  alpha=0.000
# [SAC pretrain] it=844000  bc=1.5319e-08  q=9.3604e+00  alpha=0.000
# [SAC pretrain] it=846000  bc=1.7958e-08  q=7.7381e+00  alpha=0.000
# [SAC pretrain] it=848000  bc=1.5412e-08  q=1.0280e+01  alpha=0.000
# [SAC pretrain] it=850000  bc=1.2855e-08  q=9.0202e+00  alpha=0.000
# [SAC pretrain] it=852000  bc=1.5568e-08  q=8.9088e+00  alpha=0.000
# [SAC pretrain] it=854000  bc=1.9600e-08  q=8.9523e+00  alpha=0.000
# [SAC pretrain] it=856000  bc=1.0986e-08  q=1.0748e+01  alpha=0.000
# [SAC pretrain] it=858000  bc=1.5536e-08  q=8.0481e+00  alpha=0.000
# [SAC pretrain] it=860000  bc=8.8737e-09  q=1.0524e+01  alpha=0.000
# [SAC pretrain] it=862000  bc=1.6175e-08  q=1.0495e+01  alpha=0.000
# [SAC pretrain] it=864000  bc=2.0026e-08  q=1.0955e+01  alpha=0.000
# [SAC pretrain] it=866000  bc=1.9165e-08  q=1.1192e+01  alpha=0.000
# [SAC pretrain] it=868000  bc=1.6553e-08  q=8.7285e+00  alpha=0.000
# [SAC pretrain] it=870000  bc=9.7270e-09  q=1.0661e+01  alpha=0.000
# [SAC pretrain] it=872000  bc=1.1741e-08  q=8.6176e+00  alpha=0.000
# [SAC pretrain] it=874000  bc=1.3202e-08  q=9.2562e+00  alpha=0.000
# [SAC pretrain] it=876000  bc=1.4990e-08  q=8.9460e+00  alpha=0.000
# [SAC pretrain] it=878000  bc=1.6589e-08  q=8.2517e+00  alpha=0.000
# [SAC pretrain] it=880000  bc=1.4656e-08  q=8.4767e+00  alpha=0.000
# [SAC pretrain] it=882000  bc=1.4416e-08  q=8.0813e+00  alpha=0.000
# [SAC pretrain] it=884000  bc=1.5896e-08  q=8.7365e+00  alpha=0.000
# [SAC pretrain] it=886000  bc=1.7753e-08  q=1.0392e+01  alpha=0.000
# [SAC pretrain] it=888000  bc=2.1585e-08  q=9.8340e+00  alpha=0.000
# [SAC pretrain] it=890000  bc=1.3717e-08  q=9.5894e+00  alpha=0.000
# [SAC pretrain] it=892000  bc=1.7818e-08  q=9.0730e+00  alpha=0.000
# [SAC pretrain] it=894000  bc=1.4803e-08  q=8.9797e+00  alpha=0.000
# [SAC pretrain] it=896000  bc=1.4863e-08  q=1.0277e+01  alpha=0.000
# [SAC pretrain] it=898000  bc=1.7195e-08  q=9.6823e+00  alpha=0.000
# [SAC pretrain] it=900000  bc=1.2971e-08  q=1.1572e+01  alpha=0.000
# [SAC pretrain] it=902000  bc=1.5784e-08  q=1.0041e+01  alpha=0.000
# [SAC pretrain] it=904000  bc=2.5786e-08  q=8.6435e+00  alpha=0.000
# [SAC pretrain] it=906000  bc=1.4618e-08  q=8.4986e+00  alpha=0.000
# [SAC pretrain] it=908000  bc=1.1532e-08  q=1.0263e+01  alpha=0.000
# [SAC pretrain] it=910000  bc=2.1034e-08  q=1.0240e+01  alpha=0.000
# [SAC pretrain] it=912000  bc=1.4747e-08  q=1.0165e+01  alpha=0.000
# [SAC pretrain] it=914000  bc=1.2851e-08  q=1.0451e+01  alpha=0.000
# [SAC pretrain] it=916000  bc=2.1826e-08  q=9.3570e+00  alpha=0.000
# [SAC pretrain] it=918000  bc=1.4429e-08  q=8.5681e+00  alpha=0.000
# [SAC pretrain] it=920000  bc=1.5890e-08  q=8.6072e+00  alpha=0.000
# [SAC pretrain] it=922000  bc=1.5392e-08  q=8.9872e+00  alpha=0.000
# [SAC pretrain] it=924000  bc=1.7567e-08  q=8.7679e+00  alpha=0.000
# [SAC pretrain] it=926000  bc=1.5419e-08  q=8.7993e+00  alpha=0.000
# [SAC pretrain] it=928000  bc=1.4123e-08  q=1.0405e+01  alpha=0.000
# [SAC pretrain] it=930000  bc=1.3564e-08  q=8.5665e+00  alpha=0.000
# [SAC pretrain] it=932000  bc=1.2656e-08  q=1.0048e+01  alpha=0.000
# [SAC pretrain] it=934000  bc=1.3209e-08  q=1.0248e+01  alpha=0.000
# [SAC pretrain] it=936000  bc=1.6239e-08  q=9.1532e+00  alpha=0.000
# [SAC pretrain] it=938000  bc=1.3182e-08  q=9.5569e+00  alpha=0.000
# [SAC pretrain] it=940000  bc=1.0718e-08  q=1.0809e+01  alpha=0.000
# [SAC pretrain] it=942000  bc=1.5670e-08  q=8.9147e+00  alpha=0.000
# [SAC pretrain] it=944000  bc=8.8861e-09  q=8.5513e+00  alpha=0.000
# [SAC pretrain] it=946000  bc=1.2289e-08  q=9.5381e+00  alpha=0.000
# [SAC pretrain] it=948000  bc=1.3471e-08  q=1.0510e+01  alpha=0.000
# [SAC pretrain] it=950000  bc=1.4284e-08  q=9.9407e+00  alpha=0.000
# [SAC pretrain] it=952000  bc=1.9745e-08  q=7.9924e+00  alpha=0.000
# [SAC pretrain] it=954000  bc=1.3187e-08  q=8.2925e+00  alpha=0.000
# [SAC pretrain] it=956000  bc=1.0919e-08  q=7.5622e+00  alpha=0.000
# [SAC pretrain] it=958000  bc=1.7890e-08  q=8.3484e+00  alpha=0.000
# [SAC pretrain] it=960000  bc=1.3216e-08  q=8.3215e+00  alpha=0.000
# [SAC pretrain] it=962000  bc=1.4325e-08  q=8.9666e+00  alpha=0.000
# [SAC pretrain] it=964000  bc=1.4323e-08  q=1.0277e+01  alpha=0.000
# [SAC pretrain] it=966000  bc=1.3241e-08  q=9.5755e+00  alpha=0.000
# [SAC pretrain] it=968000  bc=1.5187e-08  q=1.0199e+01  alpha=0.000
# [SAC pretrain] it=970000  bc=1.2275e-08  q=9.1430e+00  alpha=0.000
# [SAC pretrain] it=972000  bc=2.0679e-08  q=8.6859e+00  alpha=0.000
# [SAC pretrain] it=974000  bc=1.8815e-08  q=8.2108e+00  alpha=0.000
# [SAC pretrain] it=976000  bc=1.9240e-08  q=9.0980e+00  alpha=0.000
# [SAC pretrain] it=978000  bc=1.6291e-08  q=8.3039e+00  alpha=0.000
# [SAC pretrain] it=980000  bc=1.1388e-08  q=1.0808e+01  alpha=0.000
# [SAC pretrain] it=982000  bc=1.1727e-08  q=1.0055e+01  alpha=0.000
# [SAC pretrain] it=984000  bc=1.5411e-08  q=1.1951e+01  alpha=0.000
# [SAC pretrain] it=986000  bc=1.3634e-08  q=1.0358e+01  alpha=0.000
# [SAC pretrain] it=988000  bc=1.5733e-08  q=1.0501e+01  alpha=0.000
# [SAC pretrain] it=990000  bc=1.9073e-08  q=1.0552e+01  alpha=0.000
# [SAC pretrain] it=992000  bc=2.0652e-08  q=1.1688e+01  alpha=0.000
# [SAC pretrain] it=994000  bc=1.4380e-08  q=1.2052e+01  alpha=0.000
# [SAC pretrain] it=996000  bc=1.1171e-08  q=9.6379e+00  alpha=0.000
# [SAC pretrain] it=998000  bc=1.1459e-08  q=1.0835e+01  alpha=0.000
# [SAC pretrain] it=1000000  bc=1.2055e-08  q=1.2632e+01  alpha=0.000
# [SAC pretrain] it=1002000  bc=1.1964e-08  q=1.2883e+01  alpha=0.000
# [SAC pretrain] it=1004000  bc=1.6491e-08  q=1.1778e+01  alpha=0.000
# [SAC pretrain] it=1006000  bc=1.4295e-08  q=1.0754e+01  alpha=0.000
# [SAC pretrain] it=1008000  bc=1.5814e-08  q=1.0864e+01  alpha=0.000
# [SAC pretrain] it=1010000  bc=1.2816e-08  q=9.1113e+00  alpha=0.000
# [SAC pretrain] it=1012000  bc=1.2744e-08  q=8.6035e+00  alpha=0.000
# [SAC pretrain] it=1014000  bc=1.6625e-08  q=9.4438e+00  alpha=0.000
# [SAC pretrain] it=1016000  bc=1.7240e-08  q=1.2377e+01  alpha=0.000
# [SAC pretrain] it=1018000  bc=1.5364e-08  q=1.2389e+01  alpha=0.000
# [SAC pretrain] it=1020000  bc=1.1089e-08  q=1.0595e+01  alpha=0.000
# [SAC pretrain] it=1022000  bc=1.4711e-08  q=8.5846e+00  alpha=0.000
# [SAC pretrain] it=1024000  bc=1.2133e-08  q=1.0913e+01  alpha=0.000
# [SAC pretrain] it=1026000  bc=1.4887e-08  q=9.6727e+00  alpha=0.000
# [SAC pretrain] it=1028000  bc=1.8700e-08  q=8.7327e+00  alpha=0.000
# [SAC pretrain] it=1030000  bc=1.2331e-08  q=9.5757e+00  alpha=0.000
# [SAC pretrain] it=1032000  bc=1.0588e-08  q=1.1565e+01  alpha=0.000
# [SAC pretrain] it=1034000  bc=1.3705e-08  q=1.0522e+01  alpha=0.000
# [SAC pretrain] it=1036000  bc=1.4890e-08  q=1.2946e+01  alpha=0.000
# [SAC pretrain] it=1038000  bc=1.2927e-08  q=1.1585e+01  alpha=0.000
# [SAC pretrain] it=1040000  bc=1.5915e-08  q=1.1252e+01  alpha=0.000
# [SAC pretrain] it=1042000  bc=1.5010e-08  q=1.2475e+01  alpha=0.000
# [SAC pretrain] it=1044000  bc=1.1712e-08  q=1.3000e+01  alpha=0.000
# [SAC pretrain] it=1046000  bc=1.5042e-08  q=1.3381e+01  alpha=0.000
# [SAC pretrain] it=1048000  bc=1.6568e-08  q=1.2248e+01  alpha=0.000
# [SAC pretrain] it=1050000  bc=1.7742e-08  q=1.2126e+01  alpha=0.000
# [SAC pretrain] it=1052000  bc=1.6357e-08  q=1.2858e+01  alpha=0.000
# [SAC pretrain] it=1054000  bc=1.4206e-08  q=1.0636e+01  alpha=0.000
# [SAC pretrain] it=1056000  bc=1.2078e-08  q=1.1666e+01  alpha=0.000
# [SAC pretrain] it=1058000  bc=1.2620e-08  q=9.6523e+00  alpha=0.000
# [SAC pretrain] it=1060000  bc=1.4230e-08  q=9.6134e+00  alpha=0.000
# [SAC pretrain] it=1062000  bc=1.8464e-08  q=1.0649e+01  alpha=0.000
# [SAC pretrain] it=1064000  bc=1.1179e-08  q=1.2726e+01  alpha=0.000
# [SAC pretrain] it=1066000  bc=1.1871e-08  q=9.2498e+00  alpha=0.000
# [SAC pretrain] it=1068000  bc=1.3154e-08  q=6.8143e+00  alpha=0.000
# [SAC pretrain] it=1070000  bc=1.0396e-08  q=8.4908e+00  alpha=0.000
# [SAC pretrain] it=1072000  bc=1.3472e-08  q=9.1971e+00  alpha=0.000
# [SAC pretrain] it=1074000  bc=1.5250e-08  q=9.3307e+00  alpha=0.000
# [SAC pretrain] it=1076000  bc=1.5903e-08  q=8.9715e+00  alpha=0.000
# [SAC pretrain] it=1078000  bc=2.6200e-08  q=9.8623e+00  alpha=0.000
# [SAC pretrain] it=1080000  bc=1.9939e-08  q=8.1500e+00  alpha=0.000
# [SAC pretrain] it=1082000  bc=1.5544e-08  q=1.0069e+01  alpha=0.000
# [SAC pretrain] it=1084000  bc=2.0290e-08  q=7.5255e+00  alpha=0.000
# [SAC pretrain] it=1086000  bc=2.4577e-08  q=9.9580e+00  alpha=0.000
# [SAC pretrain] it=1088000  bc=1.6261e-08  q=7.9444e+00  alpha=0.000
# [SAC pretrain] it=1090000  bc=1.9072e-08  q=1.0015e+01  alpha=0.000
# [SAC pretrain] it=1092000  bc=1.4098e-08  q=6.2957e+00  alpha=0.000
# [SAC pretrain] it=1094000  bc=1.1718e-08  q=9.6685e+00  alpha=0.000
# [SAC pretrain] it=1096000  bc=1.5959e-08  q=1.0381e+01  alpha=0.000
# [SAC pretrain] it=1098000  bc=1.1465e-08  q=9.6587e+00  alpha=0.000
# [SAC pretrain] it=1100000  bc=1.6072e-08  q=1.0362e+01  alpha=0.000
# [SAC pretrain] it=1102000  bc=1.3483e-08  q=1.0109e+01  alpha=0.000
# [SAC pretrain] it=1104000  bc=1.5165e-08  q=1.0085e+01  alpha=0.000
# [SAC pretrain] it=1106000  bc=1.4251e-08  q=1.0838e+01  alpha=0.000
# [SAC pretrain] it=1108000  bc=1.9530e-08  q=1.2293e+01  alpha=0.000
# [SAC pretrain] it=1110000  bc=1.5414e-08  q=1.1515e+01  alpha=0.000
# [SAC pretrain] it=1112000  bc=1.4345e-08  q=1.4770e+01  alpha=0.000
# [SAC pretrain] it=1114000  bc=1.3005e-08  q=1.4365e+01  alpha=0.000
# [SAC pretrain] it=1116000  bc=1.0800e-08  q=1.5596e+01  alpha=0.000
# [SAC pretrain] it=1118000  bc=2.4621e-08  q=1.5072e+01  alpha=0.000
# [SAC pretrain] it=1120000  bc=1.2728e-08  q=1.2909e+01  alpha=0.000
# [SAC pretrain] it=1122000  bc=1.7455e-08  q=1.3632e+01  alpha=0.000
# [SAC pretrain] it=1124000  bc=1.4304e-08  q=1.1223e+01  alpha=0.000
# [SAC pretrain] it=1126000  bc=1.5450e-08  q=1.3334e+01  alpha=0.000
# [SAC pretrain] it=1128000  bc=2.2118e-08  q=1.3213e+01  alpha=0.000
# [SAC pretrain] it=1130000  bc=1.2454e-08  q=1.0669e+01  alpha=0.000
# [SAC pretrain] it=1132000  bc=1.7094e-08  q=1.0387e+01  alpha=0.000
# [SAC pretrain] it=1134000  bc=1.3698e-08  q=1.0798e+01  alpha=0.000
# [SAC pretrain] it=1136000  bc=1.2364e-08  q=9.7651e+00  alpha=0.000
# [SAC pretrain] it=1138000  bc=1.6449e-08  q=8.9714e+00  alpha=0.000
# [SAC pretrain] it=1140000  bc=1.0022e-08  q=9.0072e+00  alpha=0.000
# [SAC pretrain] it=1142000  bc=1.5725e-08  q=9.0395e+00  alpha=0.000
# [SAC pretrain] it=1144000  bc=1.7265e-08  q=8.4035e+00  alpha=0.000
# [SAC pretrain] it=1146000  bc=1.6504e-08  q=9.6195e+00  alpha=0.000
# [SAC pretrain] it=1148000  bc=1.2836e-08  q=9.7883e+00  alpha=0.000
# [SAC pretrain] it=1150000  bc=1.4476e-08  q=7.8337e+00  alpha=0.000
# [SAC pretrain] it=1152000  bc=1.1394e-08  q=1.0215e+01  alpha=0.000
# [SAC pretrain] it=1154000  bc=1.5398e-08  q=1.1242e+01  alpha=0.000
# [SAC pretrain] it=1156000  bc=1.3407e-08  q=1.0783e+01  alpha=0.000
# [SAC pretrain] it=1158000  bc=1.4628e-08  q=8.8853e+00  alpha=0.000
# [SAC pretrain] it=1160000  bc=1.3395e-08  q=8.4428e+00  alpha=0.000
# [SAC pretrain] it=1162000  bc=1.2628e-08  q=9.5206e+00  alpha=0.000
# [SAC pretrain] it=1164000  bc=1.5223e-08  q=9.6141e+00  alpha=0.000
# [SAC pretrain] it=1166000  bc=1.1595e-08  q=1.0055e+01  alpha=0.000
# [SAC pretrain] it=1168000  bc=1.1821e-08  q=1.0132e+01  alpha=0.000
# [SAC pretrain] it=1170000  bc=1.3659e-08  q=1.0166e+01  alpha=0.000
# [SAC pretrain] it=1172000  bc=1.6661e-08  q=9.4862e+00  alpha=0.000
# [SAC pretrain] it=1174000  bc=1.8967e-08  q=9.1492e+00  alpha=0.000
# [SAC pretrain] it=1176000  bc=1.2731e-08  q=9.4363e+00  alpha=0.000
# [SAC pretrain] it=1178000  bc=1.1077e-08  q=1.0547e+01  alpha=0.000
# [SAC pretrain] it=1180000  bc=1.2998e-08  q=1.0853e+01  alpha=0.000
# [SAC pretrain] it=1182000  bc=1.4399e-08  q=1.0428e+01  alpha=0.000
# [SAC pretrain] it=1184000  bc=1.7567e-08  q=8.7175e+00  alpha=0.000
# [SAC pretrain] it=1186000  bc=1.6799e-08  q=9.9464e+00  alpha=0.000
# [SAC pretrain] it=1188000  bc=1.5453e-08  q=1.0176e+01  alpha=0.000
# [SAC pretrain] it=1190000  bc=1.7918e-08  q=1.2239e+01  alpha=0.000
# [SAC pretrain] it=1192000  bc=1.6567e-08  q=1.0755e+01  alpha=0.000
# [SAC pretrain] it=1194000  bc=1.5206e-08  q=1.0062e+01  alpha=0.000
# [SAC pretrain] it=1196000  bc=1.0874e-08  q=9.6251e+00  alpha=0.000
# [SAC pretrain] it=1198000  bc=1.5909e-08  q=1.0512e+01  alpha=0.000
# [SAC pretrain] it=1200000  bc=1.4377e-08  q=1.1629e+01  alpha=0.000
# [SAC pretrain] it=1202000  bc=1.1485e-08  q=1.0504e+01  alpha=0.000
# [SAC pretrain] it=1204000  bc=1.1507e-08  q=1.2780e+01  alpha=0.000
# [SAC pretrain] it=1206000  bc=1.2566e-08  q=1.2593e+01  alpha=0.000
# [SAC pretrain] it=1208000  bc=1.7779e-08  q=1.0889e+01  alpha=0.000
# [SAC pretrain] it=1210000  bc=1.2794e-08  q=9.5835e+00  alpha=0.000
# [SAC pretrain] it=1212000  bc=1.4409e-08  q=1.2219e+01  alpha=0.000
# [SAC pretrain] it=1214000  bc=1.4281e-08  q=1.0218e+01  alpha=0.000
# [SAC pretrain] it=1216000  bc=1.2994e-08  q=1.1038e+01  alpha=0.000
# [SAC pretrain] it=1218000  bc=1.0900e-08  q=1.0101e+01  alpha=0.000
# [SAC pretrain] it=1220000  bc=2.0876e-08  q=1.0221e+01  alpha=0.000
# [SAC pretrain] it=1222000  bc=1.9451e-08  q=8.8699e+00  alpha=0.000
# [SAC pretrain] it=1224000  bc=1.5397e-08  q=1.1540e+01  alpha=0.000
# [SAC pretrain] it=1226000  bc=1.5993e-08  q=1.0776e+01  alpha=0.000
# [SAC pretrain] it=1228000  bc=1.5140e-08  q=9.6569e+00  alpha=0.000
# [SAC pretrain] it=1230000  bc=1.3518e-08  q=9.1198e+00  alpha=0.000
# [SAC pretrain] it=1232000  bc=1.4002e-08  q=1.1295e+01  alpha=0.000
# [SAC pretrain] it=1234000  bc=1.4663e-08  q=1.1255e+01  alpha=0.000
# [SAC pretrain] it=1236000  bc=1.5044e-08  q=1.1688e+01  alpha=0.000
# [SAC pretrain] it=1238000  bc=1.5037e-08  q=9.5207e+00  alpha=0.000
# [SAC pretrain] it=1240000  bc=1.4919e-08  q=1.0650e+01  alpha=0.000
# [SAC pretrain] it=1242000  bc=1.4166e-08  q=9.1068e+00  alpha=0.000
# [SAC pretrain] it=1244000  bc=1.5249e-08  q=9.9268e+00  alpha=0.000
# [SAC pretrain] it=1246000  bc=1.3566e-08  q=9.1042e+00  alpha=0.000
# [SAC pretrain] it=1248000  bc=1.5817e-08  q=1.0102e+01  alpha=0.000
# [SAC pretrain] it=1250000  bc=1.5263e-08  q=9.4304e+00  alpha=0.000
# [SAC pretrain] it=1252000  bc=1.5403e-08  q=1.0408e+01  alpha=0.000
# [SAC pretrain] it=1254000  bc=1.2429e-08  q=1.2540e+01  alpha=0.000
# [SAC pretrain] it=1256000  bc=1.2858e-08  q=1.0368e+01  alpha=0.000
# [SAC pretrain] it=1258000  bc=1.7435e-08  q=9.5397e+00  alpha=0.000
# [SAC pretrain] it=1260000  bc=1.1903e-08  q=1.0390e+01  alpha=0.000
# [SAC pretrain] it=1262000  bc=1.6557e-08  q=8.8885e+00  alpha=0.000
# [SAC pretrain] it=1264000  bc=1.6205e-08  q=1.2870e+01  alpha=0.000
# [SAC pretrain] it=1266000  bc=1.3530e-08  q=1.2031e+01  alpha=0.000
# [SAC pretrain] it=1268000  bc=1.1962e-08  q=1.4741e+01  alpha=0.000
# [SAC pretrain] it=1270000  bc=1.4552e-08  q=1.4701e+01  alpha=0.000
# [SAC pretrain] it=1272000  bc=1.5355e-08  q=1.5504e+01  alpha=0.000
# [SAC pretrain] it=1274000  bc=1.5844e-08  q=1.0620e+01  alpha=0.000
# [SAC pretrain] it=1276000  bc=1.6060e-08  q=1.5334e+01  alpha=0.000
# [SAC pretrain] it=1278000  bc=1.6935e-08  q=1.3709e+01  alpha=0.000
# [SAC pretrain] it=1280000  bc=1.3391e-08  q=1.3654e+01  alpha=0.000
# [SAC pretrain] it=1282000  bc=1.5868e-08  q=1.4001e+01  alpha=0.000
# [SAC pretrain] it=1284000  bc=1.6980e-08  q=1.3550e+01  alpha=0.000
# [SAC pretrain] it=1286000  bc=1.4517e-08  q=1.4286e+01  alpha=0.000
# [SAC pretrain] it=1288000  bc=2.5661e-08  q=1.3718e+01  alpha=0.000
# [SAC pretrain] it=1290000  bc=1.6312e-08  q=1.3596e+01  alpha=0.000
# [SAC pretrain] it=1292000  bc=1.3979e-08  q=1.3499e+01  alpha=0.000
# [SAC pretrain] it=1294000  bc=2.2888e-08  q=1.3151e+01  alpha=0.000
# [SAC pretrain] it=1296000  bc=1.2285e-08  q=9.9585e+00  alpha=0.000
# [SAC pretrain] it=1298000  bc=1.5510e-08  q=1.2601e+01  alpha=0.000
# [SAC pretrain] it=1300000  bc=1.0312e-08  q=1.0472e+01  alpha=0.000
# [SAC pretrain] it=1302000  bc=1.5338e-08  q=1.0990e+01  alpha=0.000
# [SAC pretrain] it=1304000  bc=1.5576e-08  q=1.0147e+01  alpha=0.000
# [SAC pretrain] it=1306000  bc=1.9346e-08  q=1.1951e+01  alpha=0.000
# [SAC pretrain] it=1308000  bc=1.4518e-08  q=1.0929e+01  alpha=0.000
# [SAC pretrain] it=1310000  bc=1.4635e-08  q=1.0697e+01  alpha=0.000
# [SAC pretrain] it=1312000  bc=2.3014e-08  q=8.6984e+00  alpha=0.000
# [SAC pretrain] it=1314000  bc=1.0999e-08  q=1.0064e+01  alpha=0.000
# [SAC pretrain] it=1316000  bc=1.9676e-08  q=1.0293e+01  alpha=0.000
# [SAC pretrain] it=1318000  bc=1.7282e-08  q=7.8583e+00  alpha=0.000
# [SAC pretrain] it=1320000  bc=1.5407e-08  q=1.0189e+01  alpha=0.000
# [SAC pretrain] it=1322000  bc=1.4747e-08  q=8.9897e+00  alpha=0.000
# [SAC pretrain] it=1324000  bc=1.4578e-08  q=8.1392e+00  alpha=0.000
# [SAC pretrain] it=1326000  bc=1.1091e-08  q=9.9602e+00  alpha=0.000
# [SAC pretrain] it=1328000  bc=2.3223e-08  q=8.4553e+00  alpha=0.000
# [SAC pretrain] it=1330000  bc=1.8046e-08  q=9.7757e+00  alpha=0.000
# [SAC pretrain] it=1332000  bc=1.0161e-08  q=1.1888e+01  alpha=0.000
# [SAC pretrain] it=1334000  bc=1.3426e-08  q=1.1441e+01  alpha=0.000
# [SAC pretrain] it=1336000  bc=1.4987e-08  q=1.0418e+01  alpha=0.000
# [SAC pretrain] it=1338000  bc=1.2144e-08  q=1.2063e+01  alpha=0.000
# [SAC pretrain] it=1340000  bc=1.4268e-08  q=1.3074e+01  alpha=0.000
# [SAC pretrain] it=1342000  bc=2.0978e-08  q=1.1212e+01  alpha=0.000
# [SAC pretrain] it=1344000  bc=1.2326e-08  q=9.4186e+00  alpha=0.000
# [SAC pretrain] it=1346000  bc=1.0319e-08  q=1.2264e+01  alpha=0.000
# [SAC pretrain] it=1348000  bc=1.5795e-08  q=1.1476e+01  alpha=0.000
# [SAC pretrain] it=1350000  bc=1.1869e-08  q=1.0701e+01  alpha=0.000
# [SAC pretrain] it=1352000  bc=1.8049e-08  q=1.3002e+01  alpha=0.000
# [SAC pretrain] it=1354000  bc=1.7002e-08  q=1.3079e+01  alpha=0.000
# [SAC pretrain] it=1356000  bc=1.7271e-08  q=1.1085e+01  alpha=0.000
# [SAC pretrain] it=1358000  bc=1.4195e-08  q=1.3809e+01  alpha=0.000
# [SAC pretrain] it=1360000  bc=1.3326e-08  q=1.3369e+01  alpha=0.000
# [SAC pretrain] it=1362000  bc=1.3919e-08  q=1.1172e+01  alpha=0.000
# [SAC pretrain] it=1364000  bc=1.1064e-08  q=9.6936e+00  alpha=0.000
# [SAC pretrain] it=1366000  bc=1.3213e-08  q=1.0817e+01  alpha=0.000
# [SAC pretrain] it=1368000  bc=1.7471e-08  q=1.0825e+01  alpha=0.000
# [SAC pretrain] it=1370000  bc=1.5680e-08  q=1.1458e+01  alpha=0.000
# [SAC pretrain] it=1372000  bc=1.7045e-08  q=9.5595e+00  alpha=0.000
# [SAC pretrain] it=1374000  bc=1.5150e-08  q=1.0636e+01  alpha=0.000
# [SAC pretrain] it=1376000  bc=1.6301e-08  q=1.0883e+01  alpha=0.000
# [SAC pretrain] it=1378000  bc=1.0595e-08  q=1.0698e+01  alpha=0.000
# [SAC pretrain] it=1380000  bc=1.4995e-08  q=9.4096e+00  alpha=0.000
# [SAC pretrain] it=1382000  bc=1.0387e-08  q=8.2748e+00  alpha=0.000
# [SAC pretrain] it=1384000  bc=2.5048e-08  q=8.6126e+00  alpha=0.000
# [SAC pretrain] it=1386000  bc=1.4138e-08  q=1.2262e+01  alpha=0.000
# [SAC pretrain] it=1388000  bc=1.8359e-08  q=8.2607e+00  alpha=0.000
# [SAC pretrain] it=1390000  bc=1.8837e-08  q=1.1381e+01  alpha=0.000
# [SAC pretrain] it=1392000  bc=1.5147e-08  q=8.8495e+00  alpha=0.000
# [SAC pretrain] it=1394000  bc=2.1251e-08  q=1.1091e+01  alpha=0.000
# [SAC pretrain] it=1396000  bc=1.5770e-08  q=8.3169e+00  alpha=0.000
# [SAC pretrain] it=1398000  bc=1.2258e-08  q=1.0536e+01  alpha=0.000
# [SAC pretrain] it=1400000  bc=1.0668e-08  q=1.0601e+01  alpha=0.000
# [SAC pretrain] it=1402000  bc=1.4688e-08  q=8.1465e+00  alpha=0.000
# [SAC pretrain] it=1404000  bc=1.2304e-08  q=9.9900e+00  alpha=0.000
# [SAC pretrain] it=1406000  bc=1.6890e-08  q=9.7327e+00  alpha=0.000
# [SAC pretrain] it=1408000  bc=2.0458e-08  q=1.0095e+01  alpha=0.000
# [SAC pretrain] it=1410000  bc=2.0327e-08  q=1.1637e+01  alpha=0.000
# [SAC pretrain] it=1412000  bc=1.5362e-08  q=1.0875e+01  alpha=0.000
# [SAC pretrain] it=1414000  bc=1.3419e-08  q=8.4036e+00  alpha=0.000
# [SAC pretrain] it=1416000  bc=1.7040e-08  q=1.5090e+01  alpha=0.000
# [SAC pretrain] it=1418000  bc=1.3710e-08  q=1.1360e+01  alpha=0.000
# [SAC pretrain] it=1420000  bc=1.0997e-08  q=1.0359e+01  alpha=0.000
# [SAC pretrain] it=1422000  bc=1.6308e-08  q=9.3158e+00  alpha=0.000
# [SAC pretrain] it=1424000  bc=1.6184e-08  q=1.0062e+01  alpha=0.000
# [SAC pretrain] it=1426000  bc=1.5601e-08  q=1.2569e+01  alpha=0.000
# [SAC pretrain] it=1428000  bc=1.3154e-08  q=1.1357e+01  alpha=0.000
# [SAC pretrain] it=1430000  bc=1.2980e-08  q=1.3742e+01  alpha=0.000
# [SAC pretrain] it=1432000  bc=1.2645e-08  q=1.3152e+01  alpha=0.000
# [SAC pretrain] it=1434000  bc=1.5811e-08  q=1.2367e+01  alpha=0.000
# [SAC pretrain] it=1436000  bc=1.5730e-08  q=1.3087e+01  alpha=0.000
# [SAC pretrain] it=1438000  bc=1.4246e-08  q=1.2920e+01  alpha=0.000
# [SAC pretrain] it=1440000  bc=1.1914e-08  q=1.3735e+01  alpha=0.000
# [SAC pretrain] it=1442000  bc=1.4691e-08  q=1.3939e+01  alpha=0.000
# [SAC pretrain] it=1444000  bc=1.0618e-08  q=1.4571e+01  alpha=0.000
# [SAC pretrain] it=1446000  bc=1.5578e-08  q=1.2674e+01  alpha=0.000
# [SAC pretrain] it=1448000  bc=1.2793e-08  q=1.6118e+01  alpha=0.000
# [SAC pretrain] it=1450000  bc=1.4655e-08  q=1.5509e+01  alpha=0.000
# [SAC pretrain] it=1452000  bc=1.1001e-08  q=1.3491e+01  alpha=0.000
# [SAC pretrain] it=1454000  bc=1.3972e-08  q=1.1981e+01  alpha=0.000
# [SAC pretrain] it=1456000  bc=1.2819e-08  q=1.5668e+01  alpha=0.000
# [SAC pretrain] it=1458000  bc=1.5285e-08  q=1.1738e+01  alpha=0.000
# [SAC pretrain] it=1460000  bc=1.6421e-08  q=1.6261e+01  alpha=0.000
# [SAC pretrain] it=1462000  bc=1.4471e-08  q=1.3997e+01  alpha=0.000
# [SAC pretrain] it=1464000  bc=1.5846e-08  q=1.1916e+01  alpha=0.000
# [SAC pretrain] it=1466000  bc=1.3277e-08  q=1.2994e+01  alpha=0.000
# [SAC pretrain] it=1468000  bc=1.6737e-08  q=1.2883e+01  alpha=0.000
# [SAC pretrain] it=1470000  bc=1.2436e-08  q=1.1074e+01  alpha=0.000
# [SAC pretrain] it=1472000  bc=2.0419e-08  q=1.2771e+01  alpha=0.000
# [SAC pretrain] it=1474000  bc=1.8913e-08  q=1.1467e+01  alpha=0.000
# [SAC pretrain] it=1476000  bc=1.1097e-08  q=1.0792e+01  alpha=0.000
# [SAC pretrain] it=1478000  bc=2.0601e-08  q=1.1415e+01  alpha=0.000
# [SAC pretrain] it=1480000  bc=1.3365e-08  q=1.0564e+01  alpha=0.000
# [SAC pretrain] it=1482000  bc=1.8101e-08  q=1.0791e+01  alpha=0.000
# [SAC pretrain] it=1484000  bc=1.4393e-08  q=1.1501e+01  alpha=0.000
# [SAC pretrain] it=1486000  bc=1.6167e-08  q=1.1604e+01  alpha=0.000
# [SAC pretrain] it=1488000  bc=1.5213e-08  q=1.0362e+01  alpha=0.000
# [SAC pretrain] it=1490000  bc=1.7407e-08  q=1.1247e+01  alpha=0.000
# [SAC pretrain] it=1492000  bc=1.3108e-08  q=9.8360e+00  alpha=0.000
# [SAC pretrain] it=1494000  bc=1.4157e-08  q=1.0373e+01  alpha=0.000
# [SAC pretrain] it=1496000  bc=1.4126e-08  q=1.1976e+01  alpha=0.000
# [SAC pretrain] it=1498000  bc=1.6364e-08  q=1.3654e+01  alpha=0.000
# [SAC pretrain] it=1500000  bc=1.3097e-08  q=1.1347e+01  alpha=0.000

# %% [markdown]
# ## Saving and loading the agent to make sure the agent has been stored

# %%
filename_agent = sac_agent.save(dir_path, prefix="sac")
# Out:
# Saved checkpoint to: C:\Users\HAMEDI\Desktop\DistillRL\Data/models\sac_20251205_000521.pkl

# %% [markdown]
# ## Checking the accuracy of the agent and compare it to the MPC actions

# %%
@torch.no_grad()
def print_accuracy(agent, n_samples: int = 10_000):
    """
    Simple BC accuracy: sample from agent.buffer, compare actor(s) to dataset actions.
    Prints overall R^2 and per-action-dimension R^2.
    """
    device = getattr(agent, "device", torch.device("cpu"))
    if len(agent.buffer) == 0:
        print("Buffer is empty; cannot evaluate.")
        return

    B = min(n_samples, len(agent.buffer))
    sample = agent.buffer.sample(B, device=device)

    # Handle ReplayBuffer (5-tuple) or PER buffer (7-tuple)
    if len(sample) == 5:
        s, a, _, _, _ = sample
    else:
        s, a, _, _, _, _, _ = sample

    s = s.to(device).float()
    a = a.to(device).float()
    if a.ndim == 1:
        a = a.unsqueeze(-1)

    # Actor predictions: deterministic SAC policy
    pred = agent.actor.deterministic_action(s)
    pred = pred.clamp(-agent.max_action, agent.max_action)

    y_true = a.detach().cpu().numpy()
    y_pred = pred.detach().cpu().numpy()

    if y_true.shape != y_pred.shape:
        raise ValueError(f"Shape mismatch: true {y_true.shape} vs pred {y_pred.shape}.")

    eps = 1e-12
    num = np.sum((y_true - y_pred) ** 2, axis=0)
    den = np.sum((y_true - y_true.mean(axis=0, keepdims=True)) ** 2, axis=0)
    r2_per_dim = 1.0 - num / np.maximum(den, eps)
    r2_mean = float(np.mean(r2_per_dim))

    print(f"Agent R^2 vs MPC (mean over {y_true.shape[1]} actions) : {r2_mean:.6f}")
    for j, r2j in enumerate(r2_per_dim):
        print(f"  - R^2(action[{j}]): {r2j:.6f}")

# %%
print_accuracy(sac_agent, n_samples=2)
# Out:
# Agent R^2 vs MPC (mean over 2 actions) : 1.000000
#   - R^2(action[0]): 1.000000
#   - R^2(action[1]): 1.000000
